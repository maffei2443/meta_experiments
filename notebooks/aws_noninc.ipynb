# %%
from joblib import load
import numpy as np
import matplotlib.pyplot as plt

# %%
importance = load('../data/aws_ninc/importance.joblib')
fname = load('../data/aws_ninc/fnames.joblib')
dic = sorted([(k,v) for k,v in zip(importance, fname) if k > 0])
importance = [k for k,v in dic]
fname = [v for k,v in dic]
pos = np.arange(len(importance))

# %%
fig, ax1 = plt.subplots(figsize=(10,20))
fig.subplots_adjust(left=0.115, right=0.88)
ax1.set_title('Feature Importance')
ax1.xaxis.grid(True, linestyle='--', which='major',
                   color='grey', alpha=.25)
rects = plt.barh(pos, importance,
         align='center',
         tick_label=fname)

# %%
arange = 1000
difference = load('../data/aws_ninc/difference.joblib')[:arange]
cum = np.cumsum(difference)[:arange]
x = np.arange(arange)

# %%
plt.figure(figsize=(18, 6))
plt.fill_between(x, cum, 0)
plt.scatter(x, difference, s=10, c='black')
plt.axhline(0)

# %%
print(cum[-10:])
# Out:
# [-0.4 -0.4 -0.4 -0.4 -0.4 -0.4 -0.4 -0.4 -0.4 -0.4]

# %%
with open('../aws-ninc.output') as fin:
    print(fin.read())
# Out:
# [FINETUNING BASE MODELS]
# [GENERATE METAFEATURE]
# Frequency statistics in metabase:
# 	SVC                      0.940
# 	RandomForestClassifier   0.037
# 	GaussianNB               0.023
# [OFFLINE LEARNING]
# Kappa:    0.410
# GMean:    0.468
# Accuracy: 0.947
# [[278   1   3]
#  [  7   4   0]
#  [  5   0   2]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       282
#            1       0.80      0.36      0.50        11
#            2       0.40      0.29      0.33         7
#
#     accuracy                           0.95       300
#    macro avg       0.72      0.55      0.60       300
# weighted avg       0.94      0.95      0.94       300
#
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.96      0.99      0.33      0.97      0.57      0.35       282
#           1       0.80      0.36      1.00      0.50      0.60      0.34        11
#           2       0.40      0.29      0.99      0.33      0.53      0.26         7
#
# avg / total       0.94      0.95      0.37      0.94      0.57      0.35       300
#
# [ONLINE LEARNING]
# Kappa:  0.019669551534225116
# GMean:  0.0
# Accuracy:  0.9554307116104869
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      2576
#            1       0.00      0.00      0.00        39
#            2       0.07      0.04      0.05        55
#
#     accuracy                           0.96      2670
#    macro avg       0.35      0.34      0.34      2670
# weighted avg       0.93      0.96      0.94      2670
#
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.97      0.99      0.02      0.98      0.15      0.02      2576
#           1       0.00      0.00      1.00      0.00      0.00      0.00        39
#           2       0.07      0.04      0.99      0.05      0.19      0.03        55
#
# avg / total       0.93      0.96      0.06      0.94      0.14      0.02      2670
